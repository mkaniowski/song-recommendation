# %%
import pandas as pd

# %%
playlsits = pd.read_csv('E:\Michal\Dokumenty\Projekty\song-recommendation\data_sim\playlists_filtered.csv')

# %%
random_playlist = playlsits['playlistname'].sample(n=1).iloc[0]

# %%
random_playlist
# Out:
# 'Ibiza Rocks'

# %%
rand_playlist = playlsits[playlsits['playlistname'] == random_playlist]

# %%
rand_playlist
# Out:
#                                   user_id                 artistname  \
# 1443161  3c8f22e888a1aee9b90dfe5c2da8af7c                The 2 Bears
# 1443162  3c8f22e888a1aee9b90dfe5c2da8af7c             Chase & Status
# 1443163  3c8f22e888a1aee9b90dfe5c2da8af7c          Foster The People
# 1443164  3c8f22e888a1aee9b90dfe5c2da8af7c                    Spector
# 1443165  3c8f22e888a1aee9b90dfe5c2da8af7c                  Dismantle
# 1443166  3c8f22e888a1aee9b90dfe5c2da8af7c                     Netsky
# 1443167  3c8f22e888a1aee9b90dfe5c2da8af7c              Justin Martin
# 1443168  3c8f22e888a1aee9b90dfe5c2da8af7c                      Benga
# 1443169  3c8f22e888a1aee9b90dfe5c2da8af7c  Extra Curricular & Doorly
# 1443170  3c8f22e888a1aee9b90dfe5c2da8af7c                 Dot Rotten
# 1443171  3c8f22e888a1aee9b90dfe5c2da8af7c                       Zinc
# 1443172  3c8f22e888a1aee9b90dfe5c2da8af7c              High Contrast
# 1443173  3c8f22e888a1aee9b90dfe5c2da8af7c                 Alex Clare
# ...

# %%
playlist_songs_df = playlsits[playlsits['playlistname'] == random_playlist]

# %%
random_songs = playlist_songs_df['trackname'].sample(n=3).tolist()

# %%
filtered_playlists_df = playlist_songs_df[~playlist_songs_df['trackname'].isin(random_songs)]

# %%
random_playlist
# Out:
# 'Ibiza Rocks'

# %%
playlist_songs_df
# Out:
#                                   user_id                 artistname  \
# 1443161  3c8f22e888a1aee9b90dfe5c2da8af7c                The 2 Bears
# 1443162  3c8f22e888a1aee9b90dfe5c2da8af7c             Chase & Status
# 1443163  3c8f22e888a1aee9b90dfe5c2da8af7c          Foster The People
# 1443164  3c8f22e888a1aee9b90dfe5c2da8af7c                    Spector
# 1443165  3c8f22e888a1aee9b90dfe5c2da8af7c                  Dismantle
# 1443166  3c8f22e888a1aee9b90dfe5c2da8af7c                     Netsky
# 1443167  3c8f22e888a1aee9b90dfe5c2da8af7c              Justin Martin
# 1443168  3c8f22e888a1aee9b90dfe5c2da8af7c                      Benga
# 1443169  3c8f22e888a1aee9b90dfe5c2da8af7c  Extra Curricular & Doorly
# 1443170  3c8f22e888a1aee9b90dfe5c2da8af7c                 Dot Rotten
# 1443171  3c8f22e888a1aee9b90dfe5c2da8af7c                       Zinc
# 1443172  3c8f22e888a1aee9b90dfe5c2da8af7c              High Contrast
# 1443173  3c8f22e888a1aee9b90dfe5c2da8af7c                 Alex Clare
# ...

# %%
random_songs
# Out:
# ['Celestine', 'Last Day', 'Hood Rich']

# %%
filtered_playlists_df
# Out:
#                                   user_id         artistname  \
# 1443161  3c8f22e888a1aee9b90dfe5c2da8af7c        The 2 Bears
# 1443162  3c8f22e888a1aee9b90dfe5c2da8af7c     Chase & Status
# 1443163  3c8f22e888a1aee9b90dfe5c2da8af7c  Foster The People
# 1443165  3c8f22e888a1aee9b90dfe5c2da8af7c          Dismantle
# 1443166  3c8f22e888a1aee9b90dfe5c2da8af7c             Netsky
# 1443168  3c8f22e888a1aee9b90dfe5c2da8af7c              Benga
# 1443170  3c8f22e888a1aee9b90dfe5c2da8af7c         Dot Rotten
# 1443171  3c8f22e888a1aee9b90dfe5c2da8af7c               Zinc
# 1443172  3c8f22e888a1aee9b90dfe5c2da8af7c      High Contrast
# 1443173  3c8f22e888a1aee9b90dfe5c2da8af7c         Alex Clare
# 1443174  3c8f22e888a1aee9b90dfe5c2da8af7c         Theme Park
# 1443175  3c8f22e888a1aee9b90dfe5c2da8af7c         Willy Moon
#
#                         trackname playlistname
# 1443161                 Be Strong  Ibiza Rocks
# 1443162  Blind Faith - Radio Edit  Ibiza Rocks
# ...
